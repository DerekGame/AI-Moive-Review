# %%
import tensorflow
import keras

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Embedding,Activation,Dropout,SpatialDropout1D,Bidirectional,LSTM,SimpleRNN
from tensorflow.keras.layers import Conv1D,MaxPooling1D,GlobalAveragePooling1D,GlobalMaxPooling1D

import pandas as pd
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# Setting the Workspace on Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Loading the Data from the dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/SP2023/AI/Database/imdb.csv")
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# Convert Positive/Negative to 1 and 0

# %%
mapping = dict(positive=1,
               negative=0)

# creating a mapping to encode the labels
df['sentiment'] = df['sentiment'].map(mapping)

df.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %%
df.sentiment.value_counts()
# Out:
# 1    25000
# 0    25000
# Name: sentiment, dtype: int64

# %%
df.isna().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
label = df['sentiment']
label = label.to_numpy()

# %%
nltk.download('stopwords')
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
all_stopwords = stopwords.words('english')
negation = ['no','not']
all_stopwords = [w for w in all_stopwords if w not in negation]

def preprocessing(data):
    corpus = []
    for i in range(len(data)):
        # remove urls
        tweet = re.sub(r'http\S+', ' ', data[i]) # links

        # remove html tags
        tweet = re.sub(r'<.?>', ' ', tweet) # tags
        tweet = re.sub('&\w+([-.]\w+)', ' ', tweet) # colorcodes

        # remove digits
        tweet = re.sub(r'\d+', ' ', tweet)
        tweet = re.sub('@\w+([-.]\w+)*', ' ', tweet) # mentions

        # remove emojis
        emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
        tweet = emoji_pattern.sub(r'', tweet) # no emoji

        # remove hashtags
        tweet = re.sub(r'#\w+', ' ', tweet) # hashtags
        review = re.sub('[^a-zA-Z]', ' ', tweet) # any characters other than alphabets
        review = review.lower() # casefolding
        review = review.split() 
        lemma= WordNetLemmatizer() # lemmatization
        review = [lemma.lemmatize(word) for word in review if word not in all_stopwords]
        review = ' '.join(review)
        corpus.append(review)
    return corpus

review = preprocessing(df['review'])

# %%
X_train, X_test,y_train,y_test = train_test_split(review,label,test_size=0.20,stratify = label,random_state=42)

token = Tokenizer()
token.fit_on_texts(X_train)

train_sequences = token.texts_to_sequences(X_train)
valid_sequences = token.texts_to_sequences(X_test)

vocab_size = len(token.word_index)+1
vocab_size
# Out:
# 81374

# %%
maxlen = 100 # specifies the maximum length of the sequences after padding or truncating.

X_train = pad_sequences(train_sequences, maxlen=maxlen,padding = 'post')
X_test = pad_sequences(valid_sequences, maxlen=maxlen,padding = 'post')
X_train.shape
# Out:
# (40000, 100)

# %%
from keras.layers import LSTM

# %%
vec_size = 300
lstm =Sequential()
# Embedding layer
lstm.add(Embedding(input_dim = vocab_size, output_dim = vec_size,input_length=maxlen,trainable = False))
#lstm
lstm.add(LSTM(200,dropout=0.20))
lstm.add(Dense(1,activation='sigmoid'))

# %%
lstm.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
lstm_history = lstm.fit(X_train,y_train,epochs=15,validation_data=(X_test,y_test))
# Out:
# Epoch 1/15
# 1250/1250 [==============================] - 18s 9ms/step - loss: 0.6945 - accuracy: 0.5156 - val_loss: 0.6936 - val_accuracy: 0.5001
# Epoch 2/15
# 1250/1250 [==============================] - 9s 8ms/step - loss: 0.6924 - accuracy: 0.5118 - val_loss: 0.6904 - val_accuracy: 0.5239
# Epoch 3/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6965 - accuracy: 0.5059 - val_loss: 0.6957 - val_accuracy: 0.5000
# Epoch 4/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6953 - accuracy: 0.5040 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 5/15
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.6955 - accuracy: 0.5002 - val_loss: 0.6929 - val_accuracy: 0.5011
# Epoch 6/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6952 - accuracy: 0.5058 - val_loss: 0.6925 - val_accuracy: 0.5084
# Epoch 7/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6948 - accuracy: 0.5055 - val_loss: 0.7140 - val_accuracy: 0.5000
# Epoch 8/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6942 - accuracy: 0.5064 - val_loss: 0.6929 - val_accuracy: 0.5065
# Epoch 9/15
# 1250/1250 [==============================] - 11s 8ms/step - loss: 0.6930 - accuracy: 0.5168 - val_loss: 0.6927 - val_accuracy: 0.5115
# Epoch 10/15
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.6923 - accuracy: 0.5167 - val_loss: 0.6903 - val_accuracy: 0.5165
# Epoch 11/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6909 - accuracy: 0.5232 - val_loss: 0.6873 - val_accuracy: 0.5306
# Epoch 12/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6881 - accuracy: 0.5331 - val_loss: 0.6857 - val_accuracy: 0.5385
# Epoch 13/15
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.6657 - accuracy: 0.5760 - val_loss: 0.5756 - val_accuracy: 0.7041
# Epoch 14/15
# 1250/1250 [==============================] - 12s 9ms/step - loss: 0.5407 - accuracy: 0.7232 - val_loss: 0.5065 - val_accuracy: 0.7463
# Epoch 15/15
# 1250/1250 [==============================] - 11s 9ms/step - loss: 0.4963 - accuracy: 0.7546 - val_loss: 0.4634 - val_accuracy: 0.7785

# %%
import matplotlib.pyplot as plt
plt.plot(lstm_history.history['accuracy'])
plt.plot(lstm_history.history['val_accuracy'])
plt.title("LSTM Accuracy ")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.legend(['Train','Test'],loc='best')
plt.show()


plt.plot(lstm_history.history['loss'])
plt.plot(lstm_history.history['val_loss'])
plt.title("LSTM Loss ")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend(['Train','Test'],loc='best')
plt.show()

# %%
import pickle
with open ("lstm_sentiment_analysis.pkl",'wb') as f:
    pickle.dump(lstm,f)

# %%
score_lstm = lstm.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4634 - accuracy: 0.7785

# %%
print("Test loss :",score_lstm[0])
print("Test Accuracy :",score_lstm[1])
# Out:
# Test loss : 0.4634254276752472
# Test Accuracy : 0.7785000205039978
